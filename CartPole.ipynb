# %%
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch import optim
import copy
from gym import wrappers

# %%
# env = gym.make('MountainCar-v0')
env = gym.make('CartPole-v1')

action_space=[0,1]
num_states = env.observation_space.shape[0]

# %%
seed = 100
env.seed(seed)
torch.manual_seed(seed)

# %%
# Hyper - Parameters

NUMBER_OF_EPISODES = 500
hyper_parameters = {}
hyper_parameters['learning_rate'] = 0.01
hyper_parameters['max_timesteps'] = 500
hyper_parameters['epsilon'] = 0.9
hyper_parameters['epsilon_decay'] = 0.999
hyper_parameters['epsilon_min'] = 0.02
hyper_parameters['discount_factor'] = 0.995
hyper_parameters['replay_length'] = 64
hyper_parameters['batch_size'] = 32
hyper_parameters['target_update'] = 1

# %%
class Net(nn.Module):
    def __init__(self , input_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(input_dim,64)
        self.fc2 = nn.Linear(64,output_dim)

    def forward(self, x):
        output = torch.tanh(self.fc1(x))
        output = self.fc2(output)
        return output

# %%
class DQN(object):
    def __init__(self):
        self.policy_network = Net(num_states,len(action_space))
        self.target_network = Net(num_states,len(action_space))
        self.target_network.load_state_dict(self.policy_network.state_dict())
        
        self.D = []
        self.D_length = hyper_parameters['replay_length']
        self.optimizer = optim.Adam(params=self.policy_network.parameters() , lr=hyper_parameters['learning_rate'])
        self.loss_func = torch.nn.MSELoss()
    def get_action(self,state):
      
        with torch.no_grad():
            state = torch.Tensor(state)
            q_values = self.policy_network(state)
            action = torch.max(q_values,0)[1]
    
        return action.item()
  
    def update_nn(self, minibatch):#state, action, next_state, reward, done):
        for state, action, next_state, reward, done in minibatch:
          state = torch.Tensor(state)
          next_state = torch.Tensor(next_state)
      
          reward = torch.Tensor([reward])
          if done:
              target_value = reward
          else:
              next_state_values = self.policy_network(next_state).detach()
              target = torch.max(next_state_values)
              target_value = reward + hyper_parameters['discount_factor'] * target

          predicted_value = self.policy_network(state)[action].view(-1)

          loss = self.loss_func(predicted_value, target_value)

          self.optimizer.zero_grad()
          loss.backward()
          self.optimizer.step()
    
    def train(self):
      steps_total = []
      for episode in range(number_of_episodes):
        state = env.reset()
        step = 0

        if episode % hyper_parameters["target_update"] == 0:
          self.target_network.load_state_dict(self.policy_network.state_dict())
          self.target_network.eval()
        
        batch = []
        done = False
        while not done:
            step += 1
          
          

            if random.random() > hyper_parameters['epsilon']:
              action = self.get_action(state)
            else:
              action = env.action_space.sample()
              
            next_state, reward, done, info = env.step(action)

            
            # batch.append([state, action, next_state, reward, done])
            if len(self.D) >= self.D_length:
              self.D.pop(0)
            
            self.D.append([state, action, next_state, reward, done])

            
            if step%3==0:
              if len(self.D) > hyper_parameters['batch_size']:
                minibatch = random.sample(self.D, hyper_parameters['batch_size'])
                self.update_nn(minibatch)
                if hyper_parameters['epsilon'] > hyper_parameters['epsilon_min']:
                  hyper_parameters['epsilon'] *= hyper_parameters['epsilon_decay']
            # batch = []
            state = next_state

            if done:
                metrics['total_rewards'].append(step)
                metrics['epsilon_decay'].append(hyper_parameters['epsilon'])
                print("Episode : {} \t Reward : {} \t Epsilon : {}".format(episode, step, hyper_parameters['epsilon'])
                break
            
        count = 0
        for score in metrics['total_rewards'][-60:]:
          if score > 475:
            count += 1
          
                  
        if count > 40:
          break

    def execute(self,num_episodes):
        env = gym.make('CartPole-v1')
        env = wrappers.Monitor(env, "./gym-results", force=True)
        metrics['rewards_evaluation'] = []

        for episodes in range(num_episodes):
            step_count = 0
            state = env.reset()
            done = False
            while not done:
                action = self.get_action(state)
                state, reward, done, _ = env.step(action)
                if done:
                    reward = 0
                print(action,step_count)
#                 env.render()
                step_count += 1
            print(step_count)
            print("---------------end-----------------")
            metrics['rewards_evaluation'].append(step_count)
        print("Average reward : {}".format(sum(metrics['rewards_evaluation'])/len(metrics['rewards_evaluation'])))

# %%
# DQN
# %matplotlib inline
# env = gym.make('CartPole-v1')


number_of_episodes = 1000
metrics = {}
metrics['timesteps'], metrics['penalties'], metrics['rewards'], metrics['total_rewards'], metrics['epsilon_decay'] = [], [], [], [], []

CP = DQN()
CP.train()



plt.plot(metrics['total_rewards'])
plt.figtext(0.5, 0.01, "Total Rewards per episode", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
# plt.savefig('total_rewards.png')
# plt.plot(metrics['penalties'])
# plt.show()
# plt.plot(metrics['timesteps'])
# plt.show()
plt.plot(metrics['epsilon_decay'])
plt.figtext(0.5, 0.01, "Epsilon Decay", wrap=True, horizontalalignment='center', fontsize=12)
# plt.savefig('eps_decay.png')

plt.show()
# k_det.execute("deterministic")
metrics_q_det = copy.deepcopy(metrics)
PATH_1 = './CP_DQN.pth'
torch.save(CP.policy_network.state_dict(), PATH_1)
# Out:
# Episode : {} 	 Reward : {} 	 Epsilon : {} 0 26 0.9
# Episode : {} 	 Reward : {} 	 Epsilon : {} 1 11 0.8991
# Episode : {} 	 Reward : {} 	 Epsilon : {} 2 26 0.8919323245132865
# Episode : {} 	 Reward : {} 	 Epsilon : {} 3 34 0.8821699783465812
# Episode : {} 	 Reward : {} 	 Epsilon : {} 4 13 0.8786465879252672
# Episode : {} 	 Reward : {} 	 Epsilon : {} 5 20 0.8733878705367771
# Episode : {} 	 Reward : {} 	 Epsilon : {} 6 16 0.8690296563332859
# Episode : {} 	 Reward : {} 	 Epsilon : {} 7 39 0.8577998071919045
# Episode : {} 	 Reward : {} 	 Epsilon : {} 8 37 0.8475626360008509
# Episode : {} 	 Reward : {} 	 Epsilon : {} 9 32 0.8391250484297209
# Episode : {} 	 Reward : {} 	 Epsilon : {} 10 33 0.8299406865955485
# Episode : {} 	 Reward : {} 	 Epsilon : {} 11 27 0.8225010286703565
# Episode : {} 	 Reward : {} 	 Epsilon : {} 12 37 0.8126851208504656
# Episode : {} 	 Reward : {} 	 Epsilon : {} 13 20 0.8078211841606585
# Episode : {} 	 Reward : {} 	 Epsilon : {} 14 23 0.8021833718709166
# Episode : {} 	 Reward : {} 	 Epsilon : {} 15 21 0.7965849060702711
# Episode : {} 	 Reward : {} 	 Epsilon : {} 16 16 0.7926099394271136
# Episode : {} 	 Reward : {} 	 Epsilon : {} 17 15 0.7886548079072352
# Episode : {} 	 Reward : {} 	 Epsilon : {} 18 20 0.7839346931206392
# Episode : {} 	 Reward : {} 	 Epsilon : {} 19 24 0.7776851219015702
# Episode : {} 	 Reward : {} 	 Epsilon : {} 20 25 0.7714853726137985
# Episode : {} 	 Reward : {} 	 Epsilon : {} 21 109 0.744192471733886
# Episode : {} 	 Reward : {} 	 Epsilon : {} 22 46 0.7331073872734266
# Episode : {} 	 Reward : {} 	 Epsilon : {} 23 60 0.7185836977296861
# Episode : {} 	 Reward : {} 	 Epsilon : {} 24 22 0.7135686769779366
# Episode : {} 	 Reward : {} 	 Epsilon : {} 25 52 0.7015345712765669
# Episode : {} 	 Reward : {} 	 Epsilon : {} 26 34 0.6938561598719233
# Episode : {} 	 Reward : {} 	 Epsilon : {} 27 123 0.6659696926115485
# Episode : {} 	 Reward : {} 	 Epsilon : {} 28 33 0.6586805446603783
# Episode : {} 	 Reward : {} 	 Epsilon : {} 29 15 0.6553937221590105
# Episode : {} 	 Reward : {} 	 Epsilon : {} 30 29 0.6495187178630015
# Episode : {} 	 Reward : {} 	 Epsilon : {} 31 23 0.6449857040206
# Episode : {} 	 Reward : {} 	 Epsilon : {} 32 62 0.6322078050552299
# Episode : {} 	 Reward : {} 	 Epsilon : {} 33 120 0.6074064260917379
# Episode : {} 	 Reward : {} 	 Epsilon : {} 34 23 0.6031673154060654
# Episode : {} 	 Reward : {} 	 Epsilon : {} 35 18 0.5995573469690576
# Episode : {} 	 Reward : {} 	 Epsilon : {} 36 166 0.5674565085725853
# Episode : {} 	 Reward : {} 	 Epsilon : {} 37 29 0.5623697808348219
# Episode : {} 	 Reward : {} 	 Epsilon : {} 38 36 0.5556583364269156
# Episode : {} 	 Reward : {} 	 Epsilon : {} 39 27 0.5506773684938275
# Episode : {} 	 Reward : {} 	 Epsilon : {} 40 156 0.5227603212150076
# Episode : {} 	 Reward : {} 	 Epsilon : {} 41 22 0.5191119586549224
# Episode : {} 	 Reward : {} 	 Epsilon : {} 42 166 0.4913182385400758
# Episode : {} 	 Reward : {} 	 Epsilon : {} 43 134 0.4701585822460363
# Episode : {} 	 Reward : {} 	 Epsilon : {} 44 137 0.449460300971772
# Episode : {} 	 Reward : {} 	 Epsilon : {} 45 94 0.43573402442377585
# Episode : {} 	 Reward : {} 	 Epsilon : {} 46 13 0.43399370098772694
# Episode : {} 	 Reward : {} 	 Epsilon : {} 47 154 0.4124044337306038
# Episode : {} 	 Reward : {} 	 Epsilon : {} 48 232 0.3818263703673105
# Episode : {} 	 Reward : {} 	 Epsilon : {} 49 194 0.3581435759330318
# Episode : {} 	 Reward : {} 	 Epsilon : {} 50 500 0.3033389723148677
# Episode : {} 	 Reward : {} 	 Epsilon : {} 51 37 0.2997188584346011
# Episode : {} 	 Reward : {} 	 Epsilon : {} 52 500 0.2538546454842386
# Episode : {} 	 Reward : {} 	 Epsilon : {} 53 197 0.23787119261318654
# Episode : {} 	 Reward : {} 	 Epsilon : {} 54 500 0.20147116396718
# Episode : {} 	 Reward : {} 	 Epsilon : {} 55 96 0.19512302432509818
# Episode : {} 	 Reward : {} 	 Epsilon : {} 56 89 0.18954296819930294
# Episode : {} 	 Reward : {} 	 Epsilon : {} 57 72 0.18504586919282773
# Episode : {} 	 Reward : {} 	 Epsilon : {} 58 201 0.1730482078164869
# Episode : {} 	 Reward : {} 	 Epsilon : {} 59 265 0.15846380129280885
# Episode : {} 	 Reward : {} 	 Epsilon : {} 60 500 0.1342150183988117
# Episode : {} 	 Reward : {} 	 Epsilon : {} 61 79 0.13076870084009107
# Episode : {} 	 Reward : {} 	 Epsilon : {} 62 91 0.12690199684398665
# Episode : {} 	 Reward : {} 	 Epsilon : {} 63 428 0.11009504771101503
# Episode : {} 	 Reward : {} 	 Epsilon : {} 64 500 0.09324785050970816
# Episode : {} 	 Reward : {} 	 Epsilon : {} 65 386 0.08203918219007121
# Episode : {} 	 Reward : {} 	 Epsilon : {} 66 500 0.06948520897033132
# Episode : {} 	 Reward : {} 	 Epsilon : {} 67 266 0.06362903427893718
# Episode : {} 	 Reward : {} 	 Epsilon : {} 68 500 0.05389225764353614
# Episode : {} 	 Reward : {} 	 Epsilon : {} 69 28 0.05340916292585348
# Episode : {} 	 Reward : {} 	 Epsilon : {} 70 89 0.051881787426274
# Episode : {} 	 Reward : {} 	 Epsilon : {} 71 85 0.05044853978645001
# Episode : {} 	 Reward : {} 	 Epsilon : {} 72 159 0.04784311808707352
# Episode : {} 	 Reward : {} 	 Epsilon : {} 73 196 0.04483077131008139
# Episode : {} 	 Reward : {} 	 Epsilon : {} 74 344 0.03999833087876218
# Episode : {} 	 Reward : {} 	 Epsilon : {} 75 500 0.03387762170929597
# Episode : {} 	 Reward : {} 	 Epsilon : {} 76 500 0.028693528641405112
# Episode : {} 	 Reward : {} 	 Epsilon : {} 77 500 0.02430272682539634
# Episode : {} 	 Reward : {} 	 Epsilon : {} 78 21 0.024133117245136542
# Episode : {} 	 Reward : {} 	 Epsilon : {} 79 453 0.020749237652880087
# Episode : {} 	 Reward : {} 	 Epsilon : {} 80 310 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 81 248 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 82 331 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 83 284 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 84 259 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 85 241 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 86 159 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 87 127 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 88 87 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 89 180 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 90 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 91 96 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 92 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 93 291 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 94 128 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 95 148 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 96 109 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 97 119 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 98 121 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 99 149 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 100 112 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 101 113 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 102 141 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 103 94 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 104 114 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 105 99 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 106 88 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 107 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 108 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 109 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 110 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 111 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 112 91 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 113 92 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 114 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 115 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 116 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 117 456 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 118 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 119 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 120 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 121 52 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 122 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 123 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 124 452 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 125 122 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 126 100 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 127 83 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 128 145 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 129 256 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 130 192 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 131 178 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 132 177 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 133 16 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 134 234 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 135 210 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 136 161 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 137 122 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 138 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 139 24 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 140 223 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 141 98 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 142 278 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 143 36 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 144 217 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 145 268 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 146 344 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 147 382 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 148 294 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 149 179 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 150 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 151 177 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 152 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 153 87 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 154 97 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 155 97 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 156 216 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 157 411 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 158 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 159 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 160 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 161 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 162 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 163 296 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 164 106 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 165 120 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 166 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 167 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 168 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 169 117 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 170 102 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 171 62 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 172 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 173 109 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 174 170 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 175 204 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 176 298 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 177 370 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 178 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 179 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 180 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 181 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 182 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 183 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 184 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 185 140 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 186 132 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 187 141 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 188 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 189 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 190 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 191 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 192 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 193 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 194 50 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 195 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 196 500 0.019995174991810683
# Episode : {} 	 Reward : {} 	 Epsilon : {} 197 500 0.019995174991810683

# %%
num_episodes = 100
env = gym.make('CartPole-v1')
# env = wrappers.Monitor(env, "./gym-results", force=True)
metrics['rewards_evaluation'] = []

for episodes in range(num_episodes):
    step_count = 0
    state = env.reset()
    done = False
    while not done:
        action = CP.get_action(state)
        state, reward, done, _ = env.step(action)
        if done:
            reward = 0
        # print(action,step_count)
#                 env.render()
        step_count += 1
    # print(step_count)
    # print("---------------end-----------------")
    metrics['rewards_evaluation'].append(step_count)
print("Average reward : {}".format(sum(metrics['rewards_evaluation'])/len(metrics['rewards_evaluation'])))
plt.plot(metrics['rewards_evaluation'])
plt.figtext(0.5, 0.01, "Total Rewards per episode", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
# Out:
# Average reward : 500.0

# %%
import torch.nn.functional as F
class Net_DD(nn.Module):
    def __init__(self , input_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(input_dim,24)
        self.fc2 = nn.Linear(24,output_dim)

    def forward(self, x):
        output = F.relu(self.fc1(x))
        output = self.fc2(output)
        return output

# %%
class DDQN(object):
    def __init__(self):
        self.policy_network = Net(num_states,len(action_space))
        self.target_network = Net(num_states,len(action_space))
        self.target_network.load_state_dict(self.policy_network.state_dict())
        self.target_network.eval()
        self.D = []
        self.D_length = hyper_parameters['replay_length']
        self.optimizer = optim.Adam(params=self.policy_network.parameters() , lr=hyper_parameters['learning_rate'])
        self.loss_func = torch.nn.MSELoss()
    def get_action(self,state):
      
        with torch.no_grad():
            state = torch.Tensor(state)
            q_values = self.policy_network(state)
            action = torch.max(q_values,0)[1]
    
        return action.item()
  
    def update_nn(self, minibatch):#state, action, next_state, reward, done):
        for state, action, next_state, reward, done in minibatch:
          state = torch.Tensor(state)
          next_state = torch.Tensor(next_state)
      
          reward = torch.Tensor([reward])
          next_state_values = self.policy_network(next_state).detach()
          targetp = torch.max(next_state_values)
          if done:
              target_value = reward
          else:
              target = self.target_network(state)[action].view(-1)

              

              target_value = reward + hyper_parameters['discount_factor'] * targetp

          predicted_value = self.policy_network(state)[action].view(-1)

          loss = self.loss_func(predicted_value, target_value)

          self.optimizer.zero_grad()
          loss.backward()
          self.optimizer.step()
    
    def train(self):
      steps_total = []
      for episode in range(number_of_episodes):
        state = env.reset()
        step = 0

        if episode % hyper_parameters["target_update"] == 0:
          TAU = 0.5
          target_params = self.target_network.named_parameters()
          upd_params = dict(target_params)
          for model_name, model_param in self.policy_network.named_parameters():
              if model_name in target_params:
                  # Update parameter
                  upd_params[model_name].data.copy_((TAU)*model_param.data + (1-TAU)*target_params[model_param].data)
          
          self.target_network.load_state_dict(upd_params)
          self.target_network.eval()
        
        batch = []
        done = False
        while not done:
            step += 1
          
          

            if random.random() > hyper_parameters['epsilon']:
              action = self.get_action(state)
            else:
              action = env.action_space.sample()
              
            next_state, reward, done, info = env.step(action)

            
            # batch.append([state, action, next_state, reward, done])
            if len(self.D) >= self.D_length:
              self.D.pop(0)
            
            self.D.append([state, action, next_state, reward, done])

            
            if step%10==0:
              if len(self.D) > hyper_parameters['batch_size']:
                minibatch = random.sample(self.D, hyper_parameters['batch_size'])
                self.update_nn(minibatch)
                if hyper_parameters['epsilon'] > hyper_parameters['epsilon_min']:
                  hyper_parameters['epsilon'] *= hyper_parameters['epsilon_decay']
            # batch = []
            state = next_state

            if done:
                metrics['total_rewards'].append(step)
                metrics['epsilon_decay'].append(hyper_parameters['epsilon'])
                print("Episode : {} \t Reward : {} \t Epsilon : {}", episode, step, hyper_parameters['epsilon'])
                break
            
        count = 0
        for score in metrics['total_rewards'][-20:]:
          if score > 475:
            count += 1
                  
        if count > 10:
          break

    def execute(self,num_episodes):
        # env = gym.make('CartPole-v1')
        env = wrappers.Monitor(env, "./gym-results", force=True)
        metrics['rewards_evaluation'] = []

        for episodes in range(num_episodes):
            step_count = 0
            state = env.reset()
            done = False
            while not done:
                action = self.get_action(state)
                state, reward, done, _ = env.step(action)
                if done:
                    reward = 0
                print(action,step_count)
#                 env.render()
                step_count += 1
            print(step_count)
            print("---------------end-----------------")
            metrics['rewards_evaluation'].append(step_count)
        print("Average reward : {}".format(sum(metrics['rewards_evaluation'])/len(metrics['rewards_evaluation'])))

# %%
env = gym.make('CartPole-v1')

action_space=[0,1]
num_states = env.observation_space.shape[0]
seed = 30
env.seed(seed)
torch.manual_seed(seed)

# Hyper - Parameters

NUMBER_OF_EPISODES = 500
hyper_parameters = {}
hyper_parameters['learning_rate'] = 0.01
hyper_parameters['max_timesteps'] = 500
hyper_parameters['epsilon'] = 0.9
hyper_parameters['epsilon_decay'] = 0.99
hyper_parameters['epsilon_min'] = 0.02
hyper_parameters['discount_factor'] = 0.995
hyper_parameters['replay_length'] = 64
hyper_parameters['batch_size'] = 32
hyper_parameters['target_update'] = 10
# DQN
# %matplotlib inline
# env = gym.make('CartPole-v1')


number_of_episodes = 500
metrics = {}
metrics['timesteps'], metrics['penalties'], metrics['rewards'], metrics['total_rewards'], metrics['epsilon_decay'] = [], [], [], [], []

CP_Double = DDQN()
CP_Double.train()



plt.plot(metrics['total_rewards'])
plt.figtext(0.5, 0.01, "Total Rewards per episode", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
plt.savefig('total_rewards.png')
# plt.plot(metrics['penalties'])
# plt.show()
# plt.plot(metrics['timesteps'])
# plt.show()
plt.plot(metrics['epsilon_decay'])
plt.figtext(0.5, 0.01, "Epsilon Decay", wrap=True, horizontalalignment='center', fontsize=12)
plt.savefig('eps_decay.png')

plt.show()
# k_det.execute("deterministic")
metrics_DDQN = copy.deepcopy(metrics)
# Out:
# Episode : {} 	 Reward : {} 	 Epsilon : {} 0 13 0.9
# Episode : {} 	 Reward : {} 	 Epsilon : {} 1 15 0.9
# Episode : {} 	 Reward : {} 	 Epsilon : {} 2 34 0.8732691
# Episode : {} 	 Reward : {} 	 Epsilon : {} 3 44 0.8388588131162911
# Episode : {} 	 Reward : {} 	 Epsilon : {} 4 10 0.8304702249851281
# Episode : {} 	 Reward : {} 	 Epsilon : {} 5 44 0.7977463845445164
# Episode : {} 	 Reward : {} 	 Epsilon : {} 6 11 0.7897689206990712
# Episode : {} 	 Reward : {} 	 Epsilon : {} 7 14 0.7818712314920805
# Episode : {} 	 Reward : {} 	 Epsilon : {} 8 24 0.7663119939853881
# Episode : {} 	 Reward : {} 	 Epsilon : {} 9 36 0.7435517614520281
# Episode : {} 	 Reward : {} 	 Epsilon : {} 10 18 0.7361162438375077
# Episode : {} 	 Reward : {} 	 Epsilon : {} 11 12 0.7287550813991327
# Episode : {} 	 Reward : {} 	 Epsilon : {} 12 18 0.7214675305851413
# Episode : {} 	 Reward : {} 	 Epsilon : {} 13 18 0.7142528552792899
# Episode : {} 	 Reward : {} 	 Epsilon : {} 14 40 0.6861084429123933
# Episode : {} 	 Reward : {} 	 Epsilon : {} 15 103 0.6205041772821701
# Episode : {} 	 Reward : {} 	 Epsilon : {} 16 159 0.5336698017613496
# Episode : {} 	 Reward : {} 	 Epsilon : {} 17 33 0.5178192749792357
# Episode : {} 	 Reward : {} 	 Epsilon : {} 18 30 0.5024395246930774
# Episode : {} 	 Reward : {} 	 Epsilon : {} 19 14 0.49741512944614663
# Episode : {} 	 Reward : {} 	 Epsilon : {} 20 23 0.48751656837016827
# Episode : {} 	 Reward : {} 	 Epsilon : {} 21 23 0.4778149886596019
# Episode : {} 	 Reward : {} 	 Epsilon : {} 22 13 0.4730368387730059
# Episode : {} 	 Reward : {} 	 Epsilon : {} 23 15 0.46830647038527584
# Episode : {} 	 Reward : {} 	 Epsilon : {} 24 38 0.45439729990836275
# Episode : {} 	 Reward : {} 	 Epsilon : {} 25 55 0.43212731091427914
# Episode : {} 	 Reward : {} 	 Epsilon : {} 26 116 0.3869001121715043
# Episode : {} 	 Reward : {} 	 Epsilon : {} 27 24 0.3792007999392913
# Episode : {} 	 Reward : {} 	 Epsilon : {} 28 58 0.3606161876563865
# Episode : {} 	 Reward : {} 	 Epsilon : {} 29 220 0.2890809671083123
# Episode : {} 	 Reward : {} 	 Epsilon : {} 30 20 0.2833282558628569
# Episode : {} 	 Reward : {} 	 Epsilon : {} 31 67 0.26674792865928726
# Episode : {} 	 Reward : {} 	 Epsilon : {} 32 22 0.2614396448789674
# Episode : {} 	 Reward : {} 	 Epsilon : {} 33 12 0.25882524843017773
# Episode : {} 	 Reward : {} 	 Epsilon : {} 34 45 0.2486265009292875
# Episode : {} 	 Reward : {} 	 Epsilon : {} 35 10 0.24614023591999462
# Episode : {} 	 Reward : {} 	 Epsilon : {} 36 13 0.24367883356079467
# Episode : {} 	 Reward : {} 	 Epsilon : {} 37 72 0.22712459678041158
# Episode : {} 	 Reward : {} 	 Epsilon : {} 38 107 0.20540741412180666
# Episode : {} 	 Reward : {} 	 Epsilon : {} 39 18 0.20335333998058858
# Episode : {} 	 Reward : {} 	 Epsilon : {} 40 13 0.2013198065807827
# Episode : {} 	 Reward : {} 	 Epsilon : {} 41 21 0.1973135424298251
# Episode : {} 	 Reward : {} 	 Epsilon : {} 42 18 0.19534040700552685
# Episode : {} 	 Reward : {} 	 Epsilon : {} 43 11 0.1933870029354716
# Episode : {} 	 Reward : {} 	 Epsilon : {} 44 81 0.178446830930023
# Episode : {} 	 Reward : {} 	 Epsilon : {} 45 132 0.15659084562863765
# Episode : {} 	 Reward : {} 	 Epsilon : {} 46 99 0.14304843827980876
# Episode : {} 	 Reward : {} 	 Epsilon : {} 47 103 0.12937044343826234
# Episode : {} 	 Reward : {} 	 Epsilon : {} 48 82 0.1193758902984439
# Episode : {} 	 Reward : {} 	 Epsilon : {} 49 53 0.11352528387177409
# Episode : {} 	 Reward : {} 	 Epsilon : {} 50 56 0.1079614153741301
# Episode : {} 	 Reward : {} 	 Epsilon : {} 51 45 0.10370730484234203
# Episode : {} 	 Reward : {} 	 Epsilon : {} 52 87 0.09569536531669004
# Episode : {} 	 Reward : {} 	 Epsilon : {} 53 65 0.0900952868353406
# Episode : {} 	 Reward : {} 	 Epsilon : {} 54 108 0.08148056245665873
# Episode : {} 	 Reward : {} 	 Epsilon : {} 55 69 0.07671233211497255
# Episode : {} 	 Reward : {} 	 Epsilon : {} 56 335 0.055058782985734994
# Episode : {} 	 Reward : {} 	 Epsilon : {} 57 135 0.04831523957072034
# Episode : {} 	 Reward : {} 	 Epsilon : {} 58 434 0.0313615489956036
# Episode : {} 	 Reward : {} 	 Epsilon : {} 59 27 0.03073745417059109
# Episode : {} 	 Reward : {} 	 Epsilon : {} 60 13 0.03043007962888518
# Episode : {} 	 Reward : {} 	 Epsilon : {} 61 35 0.02952627583382766
# Episode : {} 	 Reward : {} 	 Epsilon : {} 62 181 0.024640083507700344
# Episode : {} 	 Reward : {} 	 Epsilon : {} 63 334 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 64 260 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 65 381 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 66 359 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 67 232 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 68 169 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 69 42 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 70 466 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 71 154 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 72 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 73 301 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 74 310 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 75 63 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 76 144 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 77 478 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 78 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 79 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 80 233 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 81 229 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 82 253 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 83 187 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 84 215 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 85 179 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 86 204 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 87 180 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 88 135 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 89 96 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 90 169 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 91 103 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 92 196 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 93 29 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 94 10 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 95 150 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 96 189 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 97 223 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 98 148 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 99 128 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 100 85 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 101 297 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 102 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 103 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 104 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 105 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 106 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 107 30 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 108 432 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 109 362 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 110 275 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 111 33 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 112 41 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 113 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 114 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 115 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 116 205 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 117 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 118 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 119 100 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 120 469 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 121 182 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 122 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 123 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 124 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 125 76 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 126 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 127 500 0.019951762291483984
# Episode : {} 	 Reward : {} 	 Epsilon : {} 128 500 0.019951762291483984

# %%
num_episodes = 100
env = gym.make('CartPole-v1')
# env = wrappers.Monitor(env, "./gym-results", force=True)
metrics['rewards_evaluation'] = []

for episodes in range(num_episodes):
    step_count = 0
    state = env.reset()
    done = False
    while not done:
        action = CP_Double.get_action(state)
        state, reward, done, _ = env.step(action)
        if done:
            reward = 0
        # print(action,step_count)
#                 env.render()
        step_count += 1
    # print(step_count)
    # print("---------------end-----------------")
    metrics['rewards_evaluation'].append(step_count)
print("Average reward : {}".format(sum(metrics['rewards_evaluation'])/len(metrics['rewards_evaluation'])))
plt.plot(metrics['rewards_evaluation'])
plt.figtext(0.5, 0.01, "Total Rewards per episode", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
# Out:
# Average reward : 500.0

# %%
plt.plot(metrics_q_det['total_rewards'])
plt.plot(metrics_DDQN['total_rewards'])


plt.figtext(0.5, 0.01, "Comparison Rewards per episode DQN vs DDQN", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
